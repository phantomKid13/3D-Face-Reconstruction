# %% [markdown]
# **Mount Google Drive Install Dependencies**

# %%
# !pwd
# %cd /gdrive/MyDrive/Face_Reconstruction
# Out:
# /gdrive/MyDrive/Face_Reconstruction
# /gdrive/MyDrive/Face_Reconstruction

# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %%
# !pip install pyngrok django pyngrok
# !pip install face-alignment chumpy

# %%
# !pip install git+https://github.com/phantomKid13/pytorch3d.git

# %%
# !ngrok authtoken 1tXGINvQfN8qnZopZJ75B1612sd_4CGozXExd3AbmuzUNGRAC
# Out:
# Authtoken saved to configuration file: /root/.ngrok2/ngrok.yml

# %%
from pyngrok import ngrok
tunnel = ngrok.connect(addr=8000,bind_tls=True)
tunnel.public_url.split('/')[2]
# Out:
# 'fade-35-195-43-11.ngrok.io'

# %%
ngrok.kill()

# %%
# !python manage.py runserver
# Out:
# Watching for file changes with StatReloader
# Performing system checks...
#
# System check identified no issues (0 silenced).
# November 10, 2021 - 08:06:47
# Django version 3.2.9, using settings 'Face_Reconstruction.settings'
# Starting development server at http://127.0.0.1:8000/
# Quit the server with CONTROL-C.
# [10/Nov/2021 08:07:02] "GET / HTTP/1.1" 200 20172
# [10/Nov/2021 08:07:02] "GET / HTTP/1.1" 200 20172
# [10/Nov/2021 08:07:03] "GET /static/css/font-awesome.min.css HTTP/1.1" 200 22822
# [10/Nov/2021 08:07:03] "GET /static/fonts/jiten0.jpeg HTTP/1.1" 200 22653
# [10/Nov/2021 08:07:03] "GET /static/css/index.css HTTP/1.1" 200 7465
# [10/Nov/2021 08:07:03] "GET /static/plugins/bootstrap.js HTTP/1.1" 200 55244
# [10/Nov/2021 08:07:03] "GET /static/plugins/jquery-1.10.2.js HTTP/1.1" 200 93104
# [10/Nov/2021 08:07:04] "GET /static/js/index.js HTTP/1.1" 200 3772
# [10/Nov/2021 08:07:04] "GET /static/fonts/fabbysam.jpeg HTTP/1.1" 200 11638
# ...
